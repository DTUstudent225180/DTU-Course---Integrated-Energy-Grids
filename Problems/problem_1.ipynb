# %% [markdown]
# Problem 1.1. Analysing solar and wind generation time series.
#
# In this exercise, you investigate the variability of wind and solar generation at different time scales. Select
# one country of your choice and plot the different representations described below.
